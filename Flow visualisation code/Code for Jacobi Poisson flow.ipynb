# %%
# The code below produces a plot of the Jacobi Poisson flow as described in the paper:
# "Visualising the flows of orthogonal polynomial expansions of the Riemann Xi-function".
# The program reads the file with pre-computed coefficients and produces an implicit plot, 
# i.e. it visualises the flow of the real roots when r varies. 
# Version 1.0, 2 april 2024.

# %%
var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
with open("ordinateszetazeros.txt", "r") as f: #file is stored on GitHub
    for row in f:
        y=float(row)
        if y < 60:
            ord.append([y,1])

z=list_plot(ord, size=15, marker="o", color = "black")

RDF=RealBallField(1024)
global m1; m1 = []; CoeffSum = 0
with open("JacobiCoeffa0b0", "r") as f:
    for row in f:
        CoeffSum= CoeffSum + RDF(row)
        m1.append([RDF(row)])
print("The sum of all the coefficients is : %3.16f = Xi(1) \n" % CoeffSum)
        
CCF=ComplexBallField(1024)
def Xi(t):
    f=CCF("0.5",0)+I*CCF(t)
    xi=f/2*(f-1)*CCF(pi).pow(-f/2)*(f/2).gamma()*f.zeta()
    return xi

def hyp(t,a,b,n):
    g=(1-t)/2
    f=CCF(g)
    hyp=f.hypergeometric([-n,n+a+b+1],[a+1])
    return hyp

def JacobiFlow(t,r):
    sum=CCF(0)
    for n in range(201):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(m1[n]))*hyp(t,CCF("0"),CCF("0"),n)
    return real_part(sum);

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(JacobiFlow(60,1)-Xi(60)))

a0=implicit_plot(lambda t,r:((RDF(JacobiFlow(t,r)))),(t,0,60),(r,0,1.1),color='black',fontsize=13,linestyle ="-",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{J}}_r(t)$',gridlines=True,plot_points=60)
show(a0 + z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is : 0.4857574296709835 = Xi(1)
#
# Ensure 20 digits accuracy at t = 60: 0.00000000638806881713 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
with open("ordinateszetazeros.txt", "r") as f: #file is stored on GitHub
    for row in f:
        y=float(row)
        if y < 60:
            ord.append([y,1])

z=list_plot(ord, size=15, marker="o", color = "black")

RDF=RealBallField(1024)
global m1; m1 = []; CoeffSum = 0
with open("JacobiCoeffa12b12", "r") as f:
    for row in f:
        CoeffSum= CoeffSum + RDF(row)
        m1.append([RDF(row)])
print("The sum of all the coefficients is : %3.16f = Xi(1) \n" % CoeffSum)
        
CCF=ComplexBallField(1024)
def Xi(t):
    f=CCF("0.5",0)+I*CCF(t)
    xi=f/2*(f-1)*CCF(pi).pow(-f/2)*(f/2).gamma()*f.zeta()
    return xi

def hyp(t,a,b,n):
    g=(1-t)/2
    f=CCF(g)
    hyp=f.hypergeometric([-n,n+a+b+1],[a+1])
    return hyp

def JacobiFlow(t,r):
    sum=CCF(0)
    for n in range(261):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(m1[n]))*hyp(t,CCF("0.5"),CCF("0.5"),n)
    return real_part(sum);

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(JacobiFlow(60,1)-Xi(60)))

a1=implicit_plot(lambda t,r:((RDF(JacobiFlow(t,r)))),(t,0,60),(r,0.2,1.1),color='black',fontsize=13,linestyle ="-",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{J}}_r(t), a=\frac{1}{2},b=\frac{1}{2}$',gridlines=True,plot_points=150)
show(a1 + z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is : 0.4857574296709835 = Xi(1)
#
# Ensure 20 digits accuracy at t = 60: 0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
with open("ordinateszetazeros.txt", "r") as f: #file is stored on GitHub
    for row in f:
        y=float(row)
        if y < 60:
            ord.append([y,1])

z=list_plot(ord, size=15, marker="o", color = "black")

RDF=RealBallField(1024)
global m1; m1 = []; CoeffSum = 0
with open("JacobiCoeffa34b34", "r") as f:
    for row in f:
        CoeffSum= CoeffSum + RDF(row)
        m1.append([RDF(row)])
print("The sum of all the coefficients is : %3.16f = Xi(1) \n" % CoeffSum)
        
CCF=ComplexBallField(1024)
def Xi(t):
    f=CCF("0.5",0)+I*CCF(t)
    xi=f/2*(f-1)*CCF(pi).pow(-f/2)*(f/2).gamma()*f.zeta()
    return xi

def hyp(t,a,b,n):
    g=(1-t)/2
    f=CCF(g)
    hyp=f.hypergeometric([-n,n+a+b+1],[a+1])
    return hyp

def JacobiFlow(t,r):
    sum=CCF(0)
    for n in range(260):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(m1[n]))*hyp(t,CCF("0.75"),CCF("0.75"),n)
    return real_part(sum);

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(JacobiFlow(60,1)-Xi(60)))

a2=implicit_plot(lambda t,r:((RDF(JacobiFlow(t,r)))),(t,0,60),(r,0.2,1.1),color='black',fontsize=13,linestyle ="-",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{J}}_r(t)$',gridlines=True,plot_points=150)
show(a2 + z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is : 0.4857574296709835 = Xi(1)
#
# Ensure 20 digits accuracy at t = 60: -0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
with open("ordinateszetazeros.txt", "r") as f: #file is stored on GitHub
    for row in f:
        y=float(row)
        if y < 60:
            ord.append([y,1])

z=list_plot(ord, size=15, marker="o", color = "black")

RDF=RealBallField(1024)
global m1; m1 = []; CoeffSum = 0
with open("JacobiCoeffa1b1", "r") as f:
    for row in f:
        CoeffSum= CoeffSum + RDF(row)
        m1.append([RDF(row)])
print("The sum of all the coefficients is : %3.16f = Xi(1) \n" % CoeffSum)
        
CCF=ComplexBallField(1024)
def Xi(t):
    f=CCF("0.5",0)+I*CCF(t)
    xi=f/2*(f-1)*CCF(pi).pow(-f/2)*(f/2).gamma()*f.zeta()
    return xi

def hyp(t,a,b,n):
    g=(1-t)/2
    f=CCF(g)
    hyp=f.hypergeometric([-n,n+a+b+1],[a+1])
    return hyp

def JacobiFlow(t,r):
    sum=CCF(0)
    for n in range(260):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(m1[n]))*hyp(t,CCF("1"),CCF("1"),n)
    return real_part(sum);

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(JacobiFlow(60,1)-Xi(60)))

a3=implicit_plot(lambda t,r:((RDF(JacobiFlow(t,r)))),(t,0,60),(r,0,1.1),color='black',linestyle ="-",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{J}}_r(t)$',gridlines=True,plot_points=60)
show(a3 + z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is : 0.4857574296709835 = Xi(1)
#
# Ensure 20 digits accuracy at t = 60: -0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
with open("ordinateszetazeros.txt", "r") as f: #file is stored on GitHub
    for row in f:
        y=float(row)
        if y < 60:
            ord.append([y,1])

z=list_plot(ord, size=15, marker="o", color = "black")

RDF=RealBallField(1024)
global m1; m1 = []; CoeffSum = 0
with open("JacobiCoeffa12b1", "r") as f:
    for row in f:
        CoeffSum= CoeffSum + RDF(row)
        m1.append([RDF(row)])
print("The sum of all the coefficients is : %3.16f = Xi(1) \n" % CoeffSum)
        
CCF=ComplexBallField(1500)
def Xi(t):
    f=CCF("0.5",0)+I*CCF(t)
    xi=f/2*(f-1)*CCF(pi).pow(-f/2)*(f/2).gamma()*f.zeta()
    return xi

def hyp(t,a,b,n):
    f=CCF((1-t)/2)
    hyp=f.hypergeometric([-n,n+a+b+1],[a+1])
    return hyp

def JacobiFlow(t,r):
    sum=CCF(0)
    for n in range(276):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(m1[n]))*hyp(t,CCF("0.5"),CCF("1"),n)
    return real_part(sum);

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(JacobiFlow(60,1)-Xi(60)))

a4=implicit_plot(lambda t,r:((RDF(JacobiFlow(t,r)))),(t,0,42),(r,0,1.5),color='black',linestyle ="-",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{J}}_r(t)$',gridlines=True,plot_points=60)
show(a4 + z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is : 0.4857574296709835 = Xi(1)
#
# Ensure 20 digits accuracy at t = 60: -0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
with open("ordinateszetazeros.txt", "r") as f: #file is stored on GitHub
    for row in f:
        y=float(row)
        if y < 60:
            ord.append([y,1])

z=list_plot(ord, size=15, marker="o", color = "black")

RDF=RealBallField(1024)
global m1; m1 = []; CoeffSum = 0
with open("JacobiCoeffam12b12", "r") as f:
    for row in f:
        CoeffSum= CoeffSum + RDF(row)
        m1.append([RDF(row)])
print("The sum of all the coefficients is : %3.16f = Xi(1) \n" % CoeffSum)
        
CCF=ComplexBallField(1500)
def Xi(t):
    f=CCF("0.5",0)+I*CCF(t)
    xi=f/2*(f-1)*CCF(pi).pow(-f/2)*(f/2).gamma()*f.zeta()
    return xi

def hyp(t,a,b,n):
    f=CCF((1-t)/2)
    hyp=f.hypergeometric([-n,n+a+b+1],[a+1])
    return hyp

def JacobiFlow(t,r):
    sum=CCF(0)
    for n in range(174):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(m1[n]))*hyp(t,CCF("-0.5"),CCF("0.5"),n)
    return real_part(sum);

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(JacobiFlow(60,1)-Xi(60)))

a41=implicit_plot(lambda t,r:((RDF(JacobiFlow(t,r)))),(t,0,42),(r,0,1.5),color='black',linestyle ="-",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{J}}_r(t)$',gridlines=True,plot_points=60)
show(a41 + z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is : 0.4857574296709835 = Xi(1)
#
# Ensure 20 digits accuracy at t = 60: 5.00278068552983601336 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
with open("ordinateszetazeros.txt", "r") as f: #file is stored on GitHub
    for row in f:
        y=float(row)
        if y < 60:
            ord.append([y,1])

z=list_plot(ord, size=15, marker="o", color = "black")

RDF=RealBallField(1024)
global m1; m1 = []; CoeffSum = 0
with open("JacobiCoeffm625d2b1", "r") as f:
    for row in f:
        CoeffSum= CoeffSum + RDF(row)
        m1.append([RDF(row)])
print("The sum of all the coefficients is : %3.16f = Xi(1) \n" % CoeffSum)
        
CCF=ComplexBallField(1024)
def Xi(t):
    f=CCF("0.5",0)+I*CCF(t)
    xi=f/2*(f-1)*CCF(pi).pow(-f/2)*(f/2).gamma()*f.zeta()
    return xi

def hyp(t,a,b,n):
    g=(1-t)/2
    f=CCF(g)
    hyp=f.hypergeometric([-n,n+a+b+1],[a+1])
    return hyp

def JacobiFlow(t,r):
    sum=CCF(0)
    for n in range(260):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(m1[n]))*hyp(t,CCF("-625.2"),CCF("1"),n)
    return real_part(sum);

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(JacobiFlow(60,1)-Xi(60)))

a5=implicit_plot(lambda t,r:((RDF(JacobiFlow(t,r)))),(t,0,28),(r,0,9),color='black',linestyle ="-",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{J}}_r(t)$',gridlines=True,plot_points=200)
show(a5,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is : 0.4857574296709835 = Xi(1)
#
# Ensure 20 digits accuracy at t = 60: 0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 1 graphics primitive

# %%
var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
for y in range(9):
    ord.append([2*pi()*(y+1),1])
z=list_plot(ord, size=15, marker="o", color = "black")

RDF=RealBallField(1024)
global m1; m1 = []; CoeffSum = 0
with open("JacobiCoeffa12b12int", "r") as f:
    for row in f:
        CoeffSum= CoeffSum + RDF(row)
        m1.append([RDF(row)])
print("The sum of all the coefficients is : %3.16f = Xin(1) \n" % CoeffSum)
        
CCF=ComplexBallField(1024)
def Xin(t):
    Xin=2*CCF(t/2).sin()/CCF(t)
    return Xin

def hyp(t,a,b,n):
    f=CCF((1-t)/2)
    hyp=f.hypergeometric([-n,n+a+b+1],[a+1])
    return hyp

def JacobiFlow(t,r):
    sum=CCF(0)
    for n in range(301):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(m1[n]))*hyp(t,CCF("0.5"),CCF("0.5"),n)
    return real_part(sum);

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(JacobiFlow(60,1)-Xin(60)))

a1i=implicit_plot(lambda t,r:((RDF(JacobiFlow(t,r)))),(t,0,60),(r,0,1.3),color='black',linestyle ="-",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{J}}_r(t)$',gridlines=True,plot_points=60)
show(a1i + z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is : 0.9588510772084060 = Xin(1)
#
# Ensure 20 digits accuracy at t = 60: -0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
for y in range(9):
    ord.append([2*pi()*(y+1),1])
z=list_plot(ord, size=15, marker="o", color = "black")

RDF=RealBallField(1024)
global m1; m1 = []; CoeffSum = 0
with open("JacobiCoeffm625d2b12int", "r") as f:
    for row in f:
        CoeffSum= CoeffSum + RDF(row)
        m1.append([RDF(row)])
print("The sum of all the coefficients is : %3.16f = Xin(1) \n" % CoeffSum)
        
CCF=ComplexBallField(1024)
def Xin(t):
    Xin=2*CCF(t/2).sin()/CCF(t)
    return Xin

def hyp(t,a,b,n):
    f=CCF((1-t)/2)
    hyp=f.hypergeometric([-n,n+a+b+1],[a+1])
    return hyp

def JacobiFlow(t,r):
    sum=CCF(0)
    for n in range(251):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(m1[n]))*hyp(t,CCF("-625.2"),CCF("0.5"),n)
    return real_part(sum);

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(JacobiFlow(60,1)-Xin(60)))

a2i=implicit_plot(lambda t,r:((RDF(JacobiFlow(t,r)))),(t,0,60),(r,0,1.3),color='black',linestyle ="-",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{J}}_r(t)$',gridlines=True,plot_points=60)
show(a2i + z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is : 0.9588510772084060 = Xin(1)
#
# Ensure 20 digits accuracy at t = 60: -0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
# %%gp
# default(realprecision, 700);
# xi(s)=s/2*(s-1)*Pi^(-s/2)*gamma(s/2)*zeta(s)
# nfact(a,b,n) = gamma(n+a+1)*2^(-1-a-b)*(2*n+a+b+1)*gamma(n+a+b+1)/(gamma(a+1)^2*gamma(n+1)*gamma(n+b+1))
# wei(x,a,b) = (1-x)^a*(1+x)^b
# coe(a,b,n) = nfact(a,b,n)*intnum(x=-1,1, xi(1/2+x*I)*hypergeom([-n,n+a+b+1],[a+1], (1-x)/2)*wei(x,a,b))
# for(n=0, 276, printf("%8.90e \n",real(coe(3/4,3/4,n))));
# Out:
# 0.420735492403948
