# %%
# The code below produces a plot of the Laguerre Poisson flow as described in the paper:
# "Visualising the flows of orthogonal polynomial expansions of the Riemann Xi-function".
# The program reads the file with pre-computed coefficients and produces an implicit plot, 
# i.e. it visualises the flow of the real roots when r varies. 
# Version 1.0, 2 april 2024.

# %%
var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
with open("ordinateszetazeros.txt", "r") as f: #file is stored on GitHub
    for row in f:
        y=float(row)
        if y < 60:
            ord.append([y,1])

z=list_plot(ord, size=15, marker="o", color = "black")

global m1; m1 = []; CoeffSum = RDF(0)
with open("Laguerrecoeffa12", "r") as f:
    for row in f:
        CoeffSum = CoeffSum + RDF(row)
        m1.append([RDF(row)])
print("The sum of all the coefficients is : %3.16f = Xi(0) \n" % CoeffSum)

CCF=ComplexBallField(1024)
def Xi(t):
    f=CCF("0.5",0)+I*CCF(t)
    xi=f/2*(f-1)*CCF(pi).pow(-f/2)*(f/2).gamma()*f.zeta()
    return xi

def hyp(t,a,n):
    hyp=CCF(t).hypergeometric([-n],[a + 1])
    return hyp

def LaguerreFlow(t,r):
    sum=CCF(0)
    for n in range(200):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(m1[n]))*hyp(t, CCF("0.5"),n) #enter parm value here!
    return real_part(sum);

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(LaguerreFlow(60,1)-Xi(60)))

a1=implicit_plot(lambda t,r:((RDF(LaguerreFlow(t,r)))),(t,0,60),(r,0.8,1.2),color='black',fontsize=13,linestyle ="-",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{L}}_r(t)$',gridlines=True,plot_points=150)
show(a1+z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is : 0.4971207781883141 = Xi(0)
#
# Ensure 20 digits accuracy at t = 60: -0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
with open("ordinateszetazeros.txt", "r") as f: #file is stored on GitHub
    for row in f:
        y=float(row)
        if y < 60:
            ord.append([y,1])

z=list_plot(ord, size=15, marker="o", color = "black")

global m1; m1 = []; CoeffSum = RDF(0)
with open("Laguerrecoeffa8", "r") as f:
    for row in f:
        CoeffSum = CoeffSum + RDF(row)
        m1.append([RDF(row)])
print("The sum of all the coefficients is : %3.16f = Xi(0) \n" % CoeffSum)

CCF=ComplexBallField(1024)
def Xi(t):
    f=CCF("0.5",0)+I*CCF(t)
    xi=f/2*(f-1)*CCF(pi).pow(-f/2)*(f/2).gamma()*f.zeta()
    return xi

def hyp(t,a,n):
    hyp=CCF(t).hypergeometric([-n],[a + 1])
    return hyp

def LaguerreFlow(t,r):
    sum=CCF(0)
    for n in range(200):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(m1[n]))*hyp(t, CCF("8"),n) #enter parm value here!
    return real_part(sum);

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(LaguerreFlow(60,1)-Xi(60)))

a2=implicit_plot(lambda t,r:((RDF(LaguerreFlow(t,r)))),(t,0,60),(r,0.8,1.2),color='black',fontsize=13,linestyle ="dashdot",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{L}}_r(t)$',gridlines=True,plot_points=150)
show(a2+z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is : 0.4971207781883141 = Xi(0)
#
# Ensure 20 digits accuracy at t = 60: 0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
with open("ordinateszetazeros.txt", "r") as f: #file is stored on GitHub
    for row in f:
        y=float(row)
        if y < 60:
            ord.append([y,1])

z=list_plot(ord, size=15, marker="o", color = "black")

global m1; m1 = []; CoeffSum = RDF(0)
with open("Laguerrecoeffa4", "r") as f:
    for row in f:
        CoeffSum = CoeffSum + RDF(row)
        m1.append([RDF(row)])
print("The sum of all the coefficients is : %3.16f = Xi(0) \n" % CoeffSum)

CCF=ComplexBallField(1024)
def Xi(t):
    f=CCF("0.5",0)+I*CCF(t)
    xi=f/2*(f-1)*CCF(pi).pow(-f/2)*(f/2).gamma()*f.zeta()
    return xi

def hyp(t,a,n):
    hyp=CCF(t).hypergeometric([-n],[a + 1])
    return hyp

def LaguerreFlow(t,r):
    sum=CCF(0)
    for n in range(200):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(m1[n]))*hyp(t, CCF("4"),n) #enter parm value here!
    return real_part(sum);

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(LaguerreFlow(60,1)-Xi(60)))

a3=implicit_plot(lambda t,r:((RDF(LaguerreFlow(t,r)))),(t,0,60),(r,0.8,1.2),color='black',fontsize=13,linestyle =":",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{L}}_r(t)$',gridlines=True,plot_points=150)
show(a3+z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is : 0.4971207781883141 = Xi(0)
#
# Ensure 20 digits accuracy at t = 60: 0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
#Laguerre coefficients precomputation for a < -1
DRF=RealBallField(1500)
CCF=ComplexBallField(1500)
def Phi(x, N):
    termexp2x=-1*DRF(pi)*DRF(2*x).exp()
    termexp5x= 6*DRF(pi)*DRF(5*x/2).exp()
    termexp9x= 4*DRF(pi)*DRF(pi)*DRF(9*x/2).exp()
    sum=(DRF(0))
    for n in range(N):
        summand =  ((n+1)^4*termexp9x-(n+1)^2*termexp5x)*((n+1)^2*termexp2x).exp()   
        sum = sum + summand
    return sum

def integrand(n,y,a):
    term1=CCF(I*y)/CCF(1+I*y)
    term2=CCF(1)/CCF(1+I*y)
    integr=term1.pow(n)*term2.pow(a+1)*Phi(y.abs(),60)
    return integr

def ln(n,a,M):
    res= CCF.integral(lambda y, _: integrand(n,y,a), -M, M)
    return real_part(res)

def genlcoeffs(a,N,M):
    f = open("Laguerrecoeffam8", "w")
    for n in range(N):
        f.write(str(ln(n,a,M).mid()));f.write("\r\n")
    f.close() 
    return 0

genlcoeffs(-8,200,100)
# Out:
# 0

# %%
var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
with open("ordinateszetazeros.txt", "r") as f: #file is stored on GitHub
    for row in f:
        y=float(row)
        if y < 60:
            ord.append([y,1])

z=list_plot(ord, size=15, marker="o", color = "black")

global m1; m1 = []; CoeffSum = RDF(0)
with open("Laguerrecoeffam8", "r") as f:
    for row in f:
        CoeffSum = CoeffSum + RDF(row)
        m1.append([RDF(row)])
print("The sum of all the coefficients is : %3.16f = Xi(0) \n" % CoeffSum)

CCF=ComplexBallField(1024)
def Xi(t):
    f=CCF("0.5",0)+I*CCF(t)
    xi=f/2*(f-1)*CCF(pi).pow(-f/2)*(f/2).gamma()*f.zeta()
    return xi

def LaguerreFlow(t,r):
    sum=CCF(0)
    for n in range(200):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(m1[n]))*CCF(t).laguerre_L(n, CCF("-8")) #enter parm value here!
    return real_part(sum);

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(LaguerreFlow(60,1)-Xi(60)))

a4=implicit_plot(lambda t,r:((RDF(LaguerreFlow(t,r)))),(t,0,60),(r,0.8,1.2),color='black',fontsize=13,linestyle =":",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{L}}_r(t)$',gridlines=True,plot_points=150)
show(a4+z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is : 0.0446864077921941 = Xi(0)
#
# Ensure 20 digits accuracy at t = 60: 0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
show(a1+a2+a4,aspect_ratio='automatic')
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
var("r","t");

#Generate a plot of all ordinates of the zeros < 60 to overlay the flow graphs
var('y')
ord = []
for y in range(9):
    ord.append([2*pi()*(y+1),1])
z=list_plot(ord, size=15, marker="o", color = "red")

global m1; m1 = []; CoeffSum = RDF(0)
with open("Laguerrecoeffa12int", "r") as f:
    for row in f:
        CoeffSum = CoeffSum + RDF(row)
        m1.append([RDF(row)])
print("The sum of all the coefficients is : %3.16f = Xin(0) \n" % CoeffSum)

CCF=ComplexBallField(1024)
def Xin(t):
    Xin=2*CCF(t/2).sin()/CCF(t)
    return Xin

def hyp(t,a,n):
    hyp=CCF(t).hypergeometric([-n],[a + 1])
    return hyp

def LaguerreFlow(t,r):
    sum=CCF(0)
    for n in range(200):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(m1[n]))*hyp(CCF(t), CCF("0.5"),n) #enter parm value here!
    return real_part(sum);

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(LaguerreFlow(60,1)-Xin(60)))

a1i=implicit_plot(lambda t,r:((RDF(LaguerreFlow(t,r)))),(t,0,60),(r,0,1.2),color='blue',linestyle ="-",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{L}}_r(t)$',gridlines=True,plot_points=90)
show(a1i + z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is : 1.0000000000000000 = Xin(0)
#
# Ensure 20 digits accuracy at t = 60: 0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
var("r","t");

#Generate a plot of all ordinates of the zeros < 60 to overlay the flow graphs
var('y')
ord = []
for y in range(9):
    ord.append([2*pi()*(y+1),1])
z=list_plot(ord, size=15, marker="o", color = "red")

global m1; m1 = []; CoeffSum = RDF(0)
with open("Laguerrecoeffa8int", "r") as f:
    for row in f:
        CoeffSum = CoeffSum + RDF(row)
        m1.append([RDF(row)])
print("The sum of all the coefficients is : %3.16f = Xin(0) \n" % CoeffSum)

CCF=ComplexBallField(1024)
def Xin(t):
    Xin=2*CCF(t/2).sin()/CCF(t)
    return Xin

def hyp(t,a,n):
    hyp=CCF(t).hypergeometric([-n],[a + 1])
    return hyp

def LaguerreFlow(t,r):
    sum=CCF(0)
    for n in range(200):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(m1[n]))*hyp(CCF(t), CCF("8"),n) #enter parm value here!
    return real_part(sum);

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(LaguerreFlow(60,1)-Xin(60)))

a2i=implicit_plot(lambda t,r:((RDF(LaguerreFlow(t,r)))),(t,0,60),(r,0,1.2),color='brown',axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{L}}_r(t)$',gridlines=True,plot_points=90)
show(a2i + z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is : 1.0000000000000000 = Xin(0)
#
# Ensure 20 digits accuracy at t = 60: -0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives
