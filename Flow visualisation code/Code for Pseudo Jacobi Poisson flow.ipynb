# %%
# The code below produces a plot of the Pseudo Jacobi Poisson flow as described in the paper:
# "Visualising the flows of orthogonal polynomial expansions of the Riemann Xi-function".
# The program reads the file with pre-computed coefficients and produces an implicit plot, 
# i.e. it visualises the flow of the real roots when r varies. 
# Version 1.0, 2 april 2024.

# %%
import csv

var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
with open("ordinateszetazeros.txt", "r") as f: #file is stored on GitHub
    for row in f:
        y=float(row)
        if y < 60:
            ord.append([y,1])

z=list_plot(ord, size=15, marker="o", color = "black")

RDF=RealBallField(512)
global m1; m1 = []; CoeffSumRe = RDF(0); CoeffSumIm = RDF(0);
with open('PseudoJacobiCoeffa12N250') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    real = []; 
    imag = [];
    for row in readCSV:
        re = RDF(row[0])
        im = RDF(row[1])
        CoeffSumRe = CoeffSumRe + re
        CoeffSumIm = CoeffSumIm + im
        real.append([re])
        imag.append([im])
print("The sum of all the coefficients is : "); 
print("Re: %3.16f = Xi(i)" % CoeffSumRe)
print("Im: %3.16f = 0" % CoeffSumIm)

CCF=ComplexBallField(1024)
def Xi(t):
    f=CCF("0.5",0)+I*CCF(t)
    xi=f/2*(f-1)*CCF(pi).pow(-f/2)*(f/2).gamma()*f.zeta()
    return xi

def hyp(t,a,N,n):
    f1=CCF("0.5",0)-I*CCF(t/2);
    f2=CCF(-N,a);
    hyp=CCF(f1).hypergeometric([-n,n-2*N-1],[f2])
    return hyp

def PseudoJacobiFlow(t,r):
    sum=CCF(0)
    for n in range(250):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(real[n]),str(imag[n]))*hyp(t,CCF("0.5"),250,n)
    return real_part(sum)

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(PseudoJacobiFlow(60,1)-Xi(60)))

a1=implicit_plot(lambda t,r:((RDF(PseudoJacobiFlow(t,r)))),(t,0,60),(r,0,1.5),color='black',fontsize=13,linestyle ="-",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{PJ}}_r(t), a=\frac{1}{2}, N=250$',gridlines=True,plot_points=150)
show(a1 + z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is :
# Re: 0.5087310387263240 = Xi(i)
# Im: -0.0000000000000000 = 0
# Ensure 20 digits accuracy at t = 60: -0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
import csv

var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
with open("ordinateszetazeros.txt", "r") as f: #file is stored on GitHub
    for row in f:
        y=float(row)
        if y < 60:
            ord.append([y,1])

z=list_plot(ord, size=15, marker="o", color = "black")

RDF=RealBallField(512)
global m1; m1 = []; CoeffSumRe = RDF(0); CoeffSumIm = RDF(0);
with open('PseudoJacobiCoeffa12N300') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    real = []; 
    imag = [];
    for row in readCSV:
        re = RDF(row[0])
        im = RDF(row[1])
        CoeffSumRe = CoeffSumRe + re
        CoeffSumIm = CoeffSumIm + im
        real.append([re])
        imag.append([im])
print("The sum of all the coefficients is : "); 
print("Re: %3.16f = Xi(i)" % CoeffSumRe)
print("Im: %3.16f = 0" % CoeffSumIm)

CCF=ComplexBallField(1024)
def Xi(t):
    f=CCF("0.5",0)+I*CCF(t)
    xi=f/2*(f-1)*CCF(pi).pow(-f/2)*(f/2).gamma()*f.zeta()
    return xi

def hyp(t,a,N,n):
    f1=CCF("0.5",0)-I*CCF(t/2);
    f2=CCF(-N,a);
    hyp=CCF(f1).hypergeometric([-n,n-2*N-1],[f2])
    return hyp

def PseudoJacobiFlow(t,r):
    sum=CCF(0)
    for n in range(300):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(real[n]),str(imag[n]))*hyp(t,CCF("0.5"),300,n)
    return real_part(sum)

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(PseudoJacobiFlow(60,1)-Xi(60)))

a11=implicit_plot(lambda t,r:((RDF(PseudoJacobiFlow(t,r)))),(t,0,60),(r,0,1.2),color='black',fontsize=13,linestyle ="-",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{PJ}}_r(t), a=\frac{1}{2}, N=300$',gridlines=True,plot_points=150)
show(a11 + z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is :
# Re: 0.5087310387263240 = Xi(i)
# Im: 0.0000000000000000 = 0
# Ensure 20 digits accuracy at t = 60: 0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
import csv

var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
with open("ordinateszetazeros.txt", "r") as f: #file is stored on GitHub
    for row in f:
        y=float(row)
        if y < 60:
            ord.append([y,1])

z=list_plot(ord, size=15, marker="o", color = "black")

RDF=RealBallField(512)
global m1; m1 = []; CoeffSumRe = RDF(0); CoeffSumIm = RDF(0);
with open('PseudoJacobiCoeffa34N250') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    real = []; 
    imag = [];
    for row in readCSV:
        re = RDF(row[0])
        im = RDF(row[1])
        CoeffSumRe = CoeffSumRe + re
        CoeffSumIm = CoeffSumIm + im
        real.append([re])
        imag.append([im])
print("The sum of all the coefficients is : "); 
print("Re: %3.16f = Xi(i)" % CoeffSumRe)
print("Im: %3.16f = 0" % CoeffSumIm)

CCF=ComplexBallField(1024)
def Xi(t):
    f=CCF("0.5",0)+I*CCF(t)
    xi=f/2*(f-1)*CCF(pi).pow(-f/2)*(f/2).gamma()*f.zeta()
    return xi

def hyp(t,a,N,n):
    f1=CCF("0.5",0)-I*CCF(t/2);
    f2=CCF(-N,a);
    hyp=CCF(f1).hypergeometric([-n,n-2*N-1],[f2])
    return hyp

def PseudoJacobiFlow(t,r):
    sum=CCF(0)
    for n in range(250):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(real[n]),str(imag[n]))*hyp(t,CCF("0.75"),250,n)
    return real_part(sum)

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(PseudoJacobiFlow(60,1)-Xi(60)))

a2=implicit_plot(lambda t,r:((RDF(PseudoJacobiFlow(t,r)))),(t,0,60),(r,0,1.5),color='black',fontsize=13,linestyle ="-",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{PJ}}_r(t)$',gridlines=True,plot_points=90)
show(a2 + z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is :
# Re: 0.5087310387263240 = Xi(i)
# Im: 0.0000000000000000 = 0
# Ensure 20 digits accuracy at t = 60: -0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
import csv

var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
with open("ordinateszetazeros.txt", "r") as f: #file is stored on GitHub
    for row in f:
        y=float(row)
        if y < 60:
            ord.append([y,1])

z=list_plot(ord, size=15, marker="o", color = "black")

RDF=RealBallField(512)
global m1; m1 = []; CoeffSumRe = RDF(0); CoeffSumIm = RDF(0);
with open('PseudoJacobiCoeffa8N250') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    real = []; 
    imag = [];
    for row in readCSV:
        re = RDF(row[0])
        im = RDF(row[1])
        CoeffSumRe = CoeffSumRe + re
        CoeffSumIm = CoeffSumIm + im
        real.append([re])
        imag.append([im])
print("The sum of all the coefficients is : "); 
print("Re: %3.16f = Xi(i)" % CoeffSumRe)
print("Im: %3.16f = 0" % CoeffSumIm)

CCF=ComplexBallField(1024)
def Xi(t):
    f=CCF("0.5",0)+I*CCF(t)
    xi=f/2*(f-1)*CCF(pi).pow(-f/2)*(f/2).gamma()*f.zeta()
    return xi

def hyp(t,a,N,n):
    f1=CCF("0.5",0)-I*CCF(t/2);
    f2=CCF(-N,a);
    hyp=CCF(f1).hypergeometric([-n,n-2*N-1],[f2])
    return hyp

def PseudoJacobiFlow(t,r):
    sum=CCF(0)
    for n in range(250):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(real[n]),str(imag[n]))*hyp(t,CCF("8"),250,n)
    return real_part(sum)

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(PseudoJacobiFlow(60,1)-Xi(60)))

a3=implicit_plot(lambda t,r:((RDF(PseudoJacobiFlow(t,r)))),(t,0,60),(r,0,1.5),color='black',fontsize=13,linestyle ="-",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{PJ}}_r(t)$',gridlines=True,plot_points=90)
show(a3 + z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is :
# Re: 0.5087310387263240 = Xi(i)
# Im: -0.0000000000000000 = 0
# Ensure 20 digits accuracy at t = 60: -0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
import csv

var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
for y in range(9):
    ord.append([2*pi()*(y+1),1])
z=list_plot(ord, size=15, marker="o", color = "black")

RDF=RealBallField(512)
global m1; m1 = []; CoeffSumRe = RDF(0); CoeffSumIm = RDF(0);
with open('PseudoJacobiCoeffa12N250int') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    real = []; 
    imag = [];
    for row in readCSV:
        re = RDF(row[0])
        im = RDF(row[1])
        CoeffSumRe = CoeffSumRe + re
        CoeffSumIm = CoeffSumIm + im
        real.append([re])
        imag.append([im])
print("The sum of all the coefficients is : "); 
print("Re: %3.16f = Xin(i)" % CoeffSumRe)
print("Im: %3.16f = 0" % CoeffSumIm)

CCF=ComplexBallField(1024)
def Xin(t):
    Xin=2*CCF(t/2).sin()/CCF(t)
    return Xin

def hyp(t,a,N,n):
    f1=CCF("0.5",0)-I*CCF(t/2);
    f2=CCF(-N,a);
    hyp=CCF(f1).hypergeometric([-n,n-2*N-1],[f2])
    return hyp

def PseudoJacobiFlow(t,r):
    sum=CCF(0)
    for n in range(250):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(real[n]),str(imag[n]))*hyp(t,CCF("0.5"),250,n)
    return real_part(sum)

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(PseudoJacobiFlow(60,1)-Xin(60)))

a1i=implicit_plot(lambda t,r:((RDF(PseudoJacobiFlow(t,r)))),(t,0,60),(r,0,1.5),color='black',fontsize=13,linestyle ="-",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{PJ}}_r(t)$',gridlines=True,plot_points=90)
show(a1i + z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is :
# Re: 1.0421906109874948 = Xin(i)
# Im: -0.0000000000000000 = 0
# Ensure 20 digits accuracy at t = 60: -0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
import csv

var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
for y in range(9):
    ord.append([2*pi()*(y+1),1])
z=list_plot(ord, size=15, marker="o", color = "black")

RDF=RealBallField(512)
global m1; m1 = []; CoeffSumRe = RDF(0); CoeffSumIm = RDF(0);
with open('PseudoJacobiCoeffa14N250int') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    real = []; 
    imag = [];
    for row in readCSV:
        re = RDF(row[0])
        im = RDF(row[1])
        CoeffSumRe = CoeffSumRe + re
        CoeffSumIm = CoeffSumIm + im
        real.append([re])
        imag.append([im])
print("The sum of all the coefficients is : "); 
print("Re: %3.16f = Xin(i)" % CoeffSumRe)
print("Im: %3.16f = 0" % CoeffSumIm)

CCF=ComplexBallField(1024)
def Xin(t):
    Xin=2*CCF(t/2).sin()/CCF(t)
    return Xin

def hyp(t,a,N,n):
    f1=CCF("0.5",0)-I*CCF(t/2);
    f2=CCF(-N,a);
    hyp=CCF(f1).hypergeometric([-n,n-2*N-1],[f2])
    return hyp

def PseudoJacobiFlow(t,r):
    sum=CCF(0)
    for n in range(250):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(real[n]),str(imag[n]))*hyp(t,CCF("0.25"),250,n)
    return real_part(sum)

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(PseudoJacobiFlow(60,1)-Xin(60)))

a1i=implicit_plot(lambda t,r:((RDF(PseudoJacobiFlow(t,r)))),(t,0,60),(r,0,1.5),color='black',fontsize=13,linestyle ="-",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{PJ}}_r(t)$',gridlines=True,plot_points=90)
show(a1i + z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is :
# Re: 1.0421906109874948 = Xin(i)
# Im: -0.0000000000000000 = 0
# Ensure 20 digits accuracy at t = 60: -0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives
