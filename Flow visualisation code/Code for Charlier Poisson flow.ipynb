# %%
# The code below produces a plot of the Charlier Poisson flow as described in the paper:
# "Visualising the flows of orthogonal polynomial expansions of the Riemann Xi-function".
# The program reads the file with pre-computed coefficients and produces an implicit plot, 
# i.e. it visualises the flow of the real roots when r varies. 
# Version 1.0, 2 april 2024.

# %%
var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
with open("ordinateszetazeros.txt", "r") as f: #file is stored on GitHub
    for row in f:
        y=float(row)
        if y < 60:
            ord.append([y,1])

z=list_plot(ord, size=15, marker="o", color = "black")

RDF=ComplexBallField(1024)
global m1; m1 = []; CoeffSum = RDF(0)
with open("CharlierCoeffa12", "r") as f:
    for row in f:
        CoeffSum = CoeffSum + RDF(row)
        m1.append([RDF(row)])
print("The sum of all the coefficients is : %3.16f = Xi(0) \n" % CoeffSum)

CCF=ComplexBallField(1024)
def Xi(t):
    f=CCF("0.5",0)+I*CCF(t)
    xi=f/2*(f-1)*CCF(pi).pow(-f/2)*(f/2).gamma()*f.zeta()
    return xi

def hyp(t,a,n):
    hyp=CCF(-1/a).hypergeometric([-n,-t],[])
    return hyp

def CharlierFlow(t,r):
    sum=CCF(0)
    for n in range(101):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(m1[n]))*hyp(CCF(t),CCF("0.5"),n)
    return real_part(sum)

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(CharlierFlow(60,1)-Xi(60)))

a1=implicit_plot(lambda t,r:(RDF(CharlierFlow(t,r))),(t,0,60),(r,0.4,1.3),color='black',fontsize=13,linestyle ="-",linewidth=1, axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{C}}_r(t)$',gridlines=True,plot_points=150)
show(a1 + z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is : 0.4971207781883141 = Xi(0)
#
# Ensure 20 digits accuracy at t = 60: -0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
with open("ordinateszetazeros.txt", "r") as f: #file is stored on GitHub
    for row in f:
        y=float(row)
        if y < 60:
            ord.append([y,1])

z=list_plot(ord, size=15, marker="o", color = "black")

RDF=ComplexBallField(1024)
global m1; m1 = []; CoeffSum = RDF(0)
with open("CharlierCoeffa34", "r") as f:
    for row in f:
        CoeffSum = CoeffSum + RDF(row)
        m1.append([RDF(row)])
print("The sum of all the coefficients is : %3.16f = Xi(0) \n" % CoeffSum)

CCF=ComplexBallField(1024)
def Xi(t):
    f=CCF("0.5",0)+I*CCF(t)
    xi=f/2*(f-1)*CCF(pi).pow(-f/2)*(f/2).gamma()*f.zeta()
    return xi

def hyp(t,a,n):
    hyp=CCF(-1/a).hypergeometric([-n,-t],[])
    return hyp

def CharlierFlow(t,r):
    sum=CCF(0)
    for n in range(101):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(m1[n]))*hyp(CCF(t),CCF("0.75"),n)
    return real_part(sum)

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(CharlierFlow(60,1)-Xi(60)))

a2=implicit_plot(lambda t,r:(RDF(CharlierFlow(t,r))),(t,0,60),(r,0.4,1.3),color='black',linestyle ="dashdot",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{C}}_r(t)$',gridlines=True,plot_points=90)
show(a2 + z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is : 0.4971207781883141 = Xi(0)
#
# Ensure 20 digits accuracy at t = 60: -0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
with open("ordinateszetazeros.txt", "r") as f: #file is stored on GitHub
    for row in f:
        y=float(row)
        if y < 60:
            ord.append([y,1])

z=list_plot(ord, size=15, marker="o", color = "black")

RDF=ComplexBallField(1024)
global m1; m1 = []; CoeffSum = RDF(0)
with open("CharlierCoeffa8", "r") as f:
    for row in f:
        CoeffSum = CoeffSum + RDF(row)
        m1.append([RDF(row)])
print("The sum of all the coefficients is : %3.16f = Xi(0) \n" % CoeffSum)

CCF=ComplexBallField(1024)
def Xi(t):
    f=CCF("0.5",0)+I*CCF(t)
    xi=f/2*(f-1)*CCF(pi).pow(-f/2)*(f/2).gamma()*f.zeta()
    return xi

def hyp(t,a,n):
    hyp=CCF(-1/a).hypergeometric([-n,-t],[])
    return hyp

def CharlierFlow(t,r):
    sum=CCF(0)
    for n in range(101):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(m1[n]))*hyp(CCF(t),CCF("8"),n)
    return real_part(sum)

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(CharlierFlow(60,1)-Xi(60)))

a3=implicit_plot(lambda t,r:(RDF(CharlierFlow(t,r))),(t,0,60),(r,0.4,1.3),color='black',fontsize=13,linestyle ="dashdot",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{C}}_r(t)$',gridlines=True,plot_points=150)
show(a3 + z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is : 0.4971207781883141 = Xi(0)
#
# Ensure 20 digits accuracy at t = 60: -0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
var("r","t");

#Generate a plot of all ordinates of the non-trivial zeros < 60 to overlay the flow graphs
var('y')
ord = []
with open("ordinateszetazeros.txt", "r") as f: #file is stored on GitHub
    for row in f:
        y=float(row)
        if y < 60:
            ord.append([y,1])

z=list_plot(ord, size=15, marker="o", color = "black")

RDF=ComplexBallField(1024)
global m1; m1 = []; CoeffSum = RDF(0)
with open("CharlierCoeffam8", "r") as f:
    for row in f:
        CoeffSum = CoeffSum + RDF(row)
        m1.append([RDF(row)])
print("The sum of all the coefficients is : %3.16f = Xi(0) \n" % CoeffSum)

CCF=ComplexBallField(1024)
def Xi(t):
    f=CCF("0.5",0)+I*CCF(t)
    xi=f/2*(f-1)*CCF(pi).pow(-f/2)*(f/2).gamma()*f.zeta()
    return xi

def hyp(t,a,n):
    hyp=CCF(-1/a).hypergeometric([-n,-t],[])
    return hyp

def CharlierFlow(t,r):
    sum=CCF(0)
    for n in range(120):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(m1[n]))*hyp(CCF(t),CCF("-8"),n)
    return real_part(sum)

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(CharlierFlow(60,1)-Xi(60)))

a4=implicit_plot(lambda t,r:(RDF(CharlierFlow(t,r))),(t,0,60),(r,0.4,1.3),color='black',fontsize=13,linestyle =":",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{C}}_r(t)$',gridlines=True,plot_points=150)
show(a4 + z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is : 0.4971207781883141 = Xi(0)
#
# Ensure 20 digits accuracy at t = 60: 0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
show(a1+a3+a4 + z,aspect_ratio='automatic')
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
var("r","t");

#Generate a plot of all ordinates of the zeros < 60 to overlay the flow graphs
var('y')
ord = []
for y in range(9):
    ord.append([2*pi()*(y+1),1])
z=list_plot(ord, size=15, marker="o", color = "black")

RDF=ComplexBallField(1024)
global m1; m1 = []; CoeffSum = RDF(0)
with open("CharlierCoeffN200am8int", "r") as f:
    for row in f:
        CoeffSum = CoeffSum + RDF(row)
        m1.append([RDF(row)])
print("The sum of all the coefficients is : %3.16f = Xi(0) \n" % CoeffSum)

CCF=ComplexBallField(1024)
def Xin(t):
    Xin=2*CCF(t/2).sin()/CCF(t)
    return Xin

def hyp(t,a,n):
    hyp=CCF(-1/a).hypergeometric([-n,-t],[])
    return hyp

def CharlierFlow(t,r):
    sum=CCF(0)
    for n in range(201):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(m1[n]))*hyp(CCF(t),CCF("-8"),n)
    return real_part(sum)

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(CharlierFlow(60,1)-Xin(60)))

a1i=implicit_plot(lambda t,r:(RDF(CharlierFlow(t,r))),(t,0,60),(r,0,1.3),color='green',linestyle ="-",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{C}}_r(t)$',gridlines=True,plot_points=90)
show(a1i + z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is : 1.0000000000000000 = Xi(0)
#
# Ensure 20 digits accuracy at t = 60: -0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
var("r","t");

#Generate a plot of all ordinates of the zeros < 60 to overlay the flow graphs
var('y')
ord = []
for y in range(9):
    ord.append([2*pi()*(y+1),1])
z=list_plot(ord, size=15, marker="o", color = "black")

RDF=ComplexBallField(1024)
global m1; m1 = []; CoeffSum = RDF(0)
with open("CharlierCoeffN200a12int", "r") as f:
    for row in f:
        CoeffSum = CoeffSum + RDF(row)
        m1.append([RDF(row)])
print("The sum of all the coefficients is : %3.16f = Xi(0) \n" % CoeffSum)

CCF=ComplexBallField(1024)
def Xin(t):
    Xin=2*CCF(t/2).sin()/CCF(t)
    return Xin

def hyp(t,a,n):
    hyp=CCF(-1/a).hypergeometric([-n,-t],[])
    return hyp

def CharlierFlow(t,r):
    sum=CCF(0)
    for n in range(201):
        sum=sum+CCF(str(r),0).pow(n)*CCF(str(m1[n]))*hyp(CCF(t),CCF("0.5"),n)
    return real_part(sum)

print("Ensure 20 digits accuracy at t = 60: %3.20f (should show 20 zeros)" % real_part(CharlierFlow(60,1)-Xin(60)))

a2i=implicit_plot(lambda t,r:(RDF(CharlierFlow(t,r))),(t,0,60),(r,0,1.3),color='blue',linestyle ="-",linewidth=1,axes_labels=['$t$','$r$'],title=r'Trajectories of the real roots of $X^{\mathcal{C}}_r(t)$',gridlines=True,plot_points=90)
show(a2i + z,aspect_ratio='automatic')
# Out:
# The sum of all the coefficients is : 1.0000000000000000 = Xi(0)
#
# Ensure 20 digits accuracy at t = 60: 0.00000000000000000000 (should show 20 zeros)
# Graphics object consisting of 2 graphics primitives

# %%
show(a1i + a2i + z,aspect_ratio='automatic')
# Out:
# Graphics object consisting of 3 graphics primitives
